# %%
#pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.9 requires protobuf<4,>=3.11, but you have protobuf 5.29.6 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow-intel 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.6 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.15.0 which is incompatible.

# %%
import os 
os.environ['GEMINI_API_KEY']='AIzaSyBNsZosxG6EKvmMUsKu5t8JpsMP_imJN5o'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
#model = genai.GenerativeModel('models/gemini-2.5-flash-preview-09-2025')
#model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response=model.generate_content('tabular format of the answer difference between ai vs ml vs genai vs agentic ai')

# %%
print(response.text)
# Out:
# Here is a comprehensive comparison between Artificial Intelligence (AI), Machine Learning (ML), Generative AI (GenAI), and Agentic AI.
#
# ### Comparison Table: AI vs. ML vs. GenAI vs. Agentic AI
#
# | Feature | Artificial Intelligence (AI) | Machine Learning (ML) | Generative AI (GenAI) | Agentic AI (AI Agents) |
# | :--- | :--- | :--- | :--- | :--- |
# | **Core Definition** | The broad field of creating systems that mimic human intelligence. | A subset of AI that allows systems to learn patterns from data without being explicitly programmed. | A subset of ML/Deep Learning focused on **creating new content**. | AI systems designed to **act autonomously** to achieve specific goals. |
# | **Primary Goal** | To simulate human reasoning and problem-solving. | To find patterns, classify data, and make predictions. | To generate novel data (text, images, audio, code). | To complete complex tasks, use tools, and make decisions independently. |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown



def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')
#model = genai.GenerativeModel('models/deep-research-pro-preview-12-2025')

# %%
# %%time
response = model.generate_content('create a table for summarize to a kid ml vs genai ')
# Out:
# CPU times: total: 0 ns
# Wall time: 1.69 s

# %%
to_markdown(response.text)
# Out:
# > Here is a simple table to help a kid understand the difference between Machine Learning (ML) and Generative AI (GenAI).
# >
# > ### ML vs. GenAI: What’s the difference?
# >
# > | Feature | Machine Learning (ML) | Generative AI (GenAI) |
# > | :--- | :--- | :--- |
# > | **Main Job** | **Sorting & Predicting** | **Creating & Making** |
# > | **What it does** | Looks at data to spot patterns or make a guess. | Uses what it learned to create something brand new. |
# > | **Think of it like...** | A **Detective** finding clues. | An **Artist** painting a picture. |
# > | **Example** | Deciding if an email is "Spam" or "Not Spam." | Writing a poem or drawing a picture of a space cat. |
# > | **The Output** | A choice (Yes/No) or a number. | A story, a song, or an image. |
# >
# > ***
# >
# > ### A Simple Analogy to Remember:
# >
# > *   **Machine Learning (ML)** is like a student studying for a math test. It looks at many examples of problems to learn how to find the **correct answer**.
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
    print(chunk.text)
# Out:
# Here is a simple table to help a kid understand the difference between Machine Learning (ML) and Generative AI (GenAI).
#
# ### ML vs. GenAI: What’s the difference?
#
# | Feature | Machine Learning (ML) | Generative AI (GenAI) |
# | :--- | :--- | :--- |
# | **Main Job** | **Sorting & Predicting** | **Creating & Making** |
# | **What it does** | Looks at data to spot patterns or make a guess. | Uses what it learned to create something brand new. |
# | **Think of it like...** | A **Detective** finding clues. | An **Artist** painting a picture. |
# | **Example** | Deciding if an email is "Spam" or "Not Spam." | Writing a poem or drawing a picture of a space cat. |
# | **The Output** | A choice (Yes/No) or a number. | A story, a song, or an image. |
#
# ***
#
# ### A Simple Analogy to Remember:
#
# *   **Machine Learning (ML)** is like a student studying for a math test. It looks at many examples of problems to learn how to find the **correct answer**.
# ...

# %% [markdown]
# # multi models

# %%
import PIL.Image
img = PIL.Image.open(r'C:\Users\Admin\Desktop\GEMINI\three-international-students-standing-holding-260nw-2481344455.webp')

img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=391x280>

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite-preview')

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown



def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > Based on the image provided, here is a description:
# >
# > Three students are standing on a set of wide, outdoor stone stairs in front of a building. They are all facing the camera and smiling.
# >
# > *   **On the left:** A woman with dark hair tied back wears a white collared shirt, blue jeans, and a black backpack. She is holding a dark-colored book.
# > *   **In the center:** A man with a short beard and glasses wears a white t-shirt under an open, black-and-white plaid shirt. He also has a backpack and is holding a yellow book or notebook.
# > *   **On the right:** A woman with long, wavy dark hair wears a black top, a light-colored button-up shirt, and a white pair of headphones around her neck. She is also holding a light blue book.
# >
# > The background shows a paved staircase leading up to a building entrance with large windows, suggesting a school or university campus setting. The lighting is bright and sunny, casting distinct shadows behind the individuals.

# %%
response = model.generate_content(['write a script for a 5sec instagram shoot to gain good view',img],stream=True)
response.resolve()

# %%
#=========================================

# %%
import PIL.Image
img1 = PIL.Image.open(r'C:\Users\Admin\Desktop\GEMINI\three-international-students-standing-holding-260nw-2481344455.webp')

img1
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=391x280>

# %%
model = genai.GenerativeModel('models/gemini-3.1-pro-preview-customtools')

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown



def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img1)
to_markdown(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
# ...
